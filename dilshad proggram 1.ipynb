# %%
a=int(input("enter a number"));
b=int(input("enter a number"));
choice=int(input("enter your choice 1:add\n 2.sub\n 3:mul\n 4:div"));
if choice==1:
    print("result:",a+b)
elif choice==2:
    print("result:",a-b)
elif choice==3:
    print("result:",a*b)
elif choice==4:
    print("result:",a/b)
else:
    print("invalid option")
# Out:
# enter a number2
# enter a number3
# enter your choice 1:add
#  2.sub
#  3:mul
#  4:div5
# invalid option

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
print("a&b",a and b)
print("aorb",a or b)
print("a!b", not b)
print("a>b",a > b)
print("a<b",a < b)
print("a<=b",a <= b)
print("a>=b",a >= b)
# Out:
# enter a number0
# enter a number1
# a&b 0
# aorb 1
# a!b False
# a>b False
# a<b True
# a<=b True
# a>=b False

# %%
dictionary_1={"name":"dilshad","age":21}
dictionary_2={"place":"mkm","pin":673602,"name":"shehal"}
dictionary_1.update(dictionary_2)
print(dictionary_1)
# Out:
# {'name': 'shehal', 'age': 21, 'place': 'mkm', 'pin': 673602}

# %%
a=int(input("ente a numberr"))
b=int(input("enter a number"))
c=int(input("enter a number"))
if a>b and b>c:
    print("greater is",a)
elif b>a and b>c:
    print("greater is",b)
else:
    print("greatest number is",c)
# Out:
# ente a numberr2
# enter a number4
# enter a number3
# greater is 4

# %%
list1=[2,3,4,5]
list2=[6,7,8,9]
list1.pop()
print(list1)
# Out:
# [2, 3, 4]

# %%
list1=[2,3,4,5]
list2=[6,7,8,9]
list1.remove(4)
print(list1)
# Out:
# [2, 3, 5]

# %%
list1=[2,3,4,5]
list2=[6,7,8,9]
list1.insert(2,8)
print(list1)
# Out:
# [2, 3, 8, 4, 5]

# %%
list1=[2,3,4,5]
list2=[6,7,8,9]
list1.append(6)
print(list1)
# Out:
# [2, 3, 4, 5, 6]

# %%
list1=[2,3,4,5]
list3=list1.copy()
print(list3)
# Out:
# [2, 3, 4, 5]
